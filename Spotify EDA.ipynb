# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_style("darkgrid")

# %% [markdown]
# ## Load data set

# %%
df=pd.read_csv("spotify.csv")

# %%
df
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %%
df.drop("Unnamed: 0", axis=1, inplace=True)
df
# Out:
#                       track_id                 artists  \
# 0       5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1       4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2       1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3       6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4       5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...                        ...                     ...
# 113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# 1                                        Ghost (Acoustic)
# 2                                          To Begin Again
# 3       Crazy Rich Asians (Original Motion Picture Sou...
# ...

# %%
df.isna().sum()
# Out:
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   track_id          114000 non-null  object
#  1   artists           113999 non-null  object
#  2   album_name        113999 non-null  object
#  3   track_name        113999 non-null  object
#  4   popularity        114000 non-null  int64
#  5   duration_ms       114000 non-null  int64
#  6   explicit          114000 non-null  bool
#  7   danceability      114000 non-null  float64
#  8   energy            114000 non-null  float64
#  9   key               114000 non-null  int64
#  10  loudness          114000 non-null  float64
#  11  mode              114000 non-null  int64
#  12  speechiness       114000 non-null  float64
#  13  acousticness      114000 non-null  float64
#  14  instrumentalness  114000 non-null  float64
#  15  liveness          114000 non-null  float64
# ...

# %%
cols=['track_id', 'artists', 'album_name', 'track_name', 'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
     'key', 'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
      'time_signature', 'track_genre']

# %%
df[cols].head(10)
# Out:
#                  track_id                               artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV                           Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A                          Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b                Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx                          Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K                      Chord Overstreet
# 5  01MVOl9KtVTNfFiBU9I7dc                          Tyrone Wells
# 6  6Vc5wAMmXdKIAM7WUoEb7N  A Great Big World;Christina Aguilera
# 7  1EzrEOXmMH3G43AXT1y7pA                            Jason Mraz
# 8  0IktbUcnAGrvD03AWnz3Q8             Jason Mraz;Colbie Caillat
# 9  7k9GuJYLp2AzqokyEdwEw2                        Ross Copperman
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# ...

# %%
a=df[cols].fillna(value=0)

# %%
a.head(10)
# Out:
#                  track_id                               artists  \
# 0  5SuOikwiRyPMVoIQDJUgSV                           Gen Hoshino
# 1  4qPNDBW1i3p13qLCt0Ki3A                          Ben Woodward
# 2  1iJBSr7s7jYXzM8EGcbK5b                Ingrid Michaelson;ZAYN
# 3  6lfxq3CG4xtTiEg7opyCyx                          Kina Grannis
# 4  5vjLSffimiIP26QG5WcN2K                      Chord Overstreet
# 5  01MVOl9KtVTNfFiBU9I7dc                          Tyrone Wells
# 6  6Vc5wAMmXdKIAM7WUoEb7N  A Great Big World;Christina Aguilera
# 7  1EzrEOXmMH3G43AXT1y7pA                            Jason Mraz
# 8  0IktbUcnAGrvD03AWnz3Q8             Jason Mraz;Colbie Caillat
# 9  7k9GuJYLp2AzqokyEdwEw2                        Ross Copperman
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# ...

# %%
df[cols].describe()
# Out:
#           popularity   duration_ms   danceability         energy  \
# count  114000.000000  1.140000e+05  114000.000000  114000.000000
# mean       33.238535  2.280292e+05       0.566800       0.641383
# std        22.305078  1.072977e+05       0.173542       0.251529
# min         0.000000  0.000000e+00       0.000000       0.000000
# 25%        17.000000  1.740660e+05       0.456000       0.472000
# 50%        35.000000  2.129060e+05       0.580000       0.685000
# 75%        50.000000  2.615060e+05       0.695000       0.854000
# max       100.000000  5.237295e+06       0.985000       1.000000
#
#                  key       loudness           mode    speechiness  \
# count  114000.000000  114000.000000  114000.000000  114000.000000
# mean        5.309140      -8.258960       0.637553       0.084652
# std         3.559987       5.029337       0.480709       0.105732
# min         0.000000     -49.531000       0.000000       0.000000
# ...

# %%
df.shape
# Out:
# (114000, 20)

# %%
df.columns
# Out:
# Index(['track_id', 'artists', 'album_name', 'track_name', 'popularity',
#        'duration_ms', 'explicit', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'time_signature', 'track_genre'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 20

# %%
df.describe()
# Out:
#           popularity   duration_ms   danceability         energy  \
# count  114000.000000  1.140000e+05  114000.000000  114000.000000
# mean       33.238535  2.280292e+05       0.566800       0.641383
# std        22.305078  1.072977e+05       0.173542       0.251529
# min         0.000000  0.000000e+00       0.000000       0.000000
# 25%        17.000000  1.740660e+05       0.456000       0.472000
# 50%        35.000000  2.129060e+05       0.580000       0.685000
# 75%        50.000000  2.615060e+05       0.695000       0.854000
# max       100.000000  5.237295e+06       0.985000       1.000000
#
#                  key       loudness           mode    speechiness  \
# count  114000.000000  114000.000000  114000.000000  114000.000000
# mean        5.309140      -8.258960       0.637553       0.084652
# std         3.559987       5.029337       0.480709       0.105732
# min         0.000000     -49.531000       0.000000       0.000000
# ...

# %% [markdown]
# # Data Analysis

# %% [markdown]
# Top 5 Most Popular Artists

# %%
top_5_artists=df.groupby("artists").count().sort_values(by="track_name", ascending=False)["track_name"][:5]
top_5_artists
# Out:
# artists
# The Beatles        279
# George Jones       271
# Stevie Wonder      236
# Linkin Park        224
# Ella Fitzgerald    222
# Name: track_name, dtype: int64

# %%
top_5_artists.plot.barh()
plt.show()

# %% [markdown]
# Top 5 Most Loudest tracks

# %%
top_5_loudest_tracks= df[['loudness','track_name']].sort_values(by="loudness", ascending=True)[:5]
top_5_loudest_tracks
# Out:
#         loudness                                    track_name
# 101888   -49.531  Soothing White Noise - Loopable With No Fade
# 101538   -49.307           White Noise - Loopable With No Fade
# 101722   -46.591                Ceiling Fan Sound on Low Power
# 101360   -46.251       Cricket Sound 4 - Loopable With No Fade
# 79719    -43.957       Chaconne in sol maggiore : Variazione 9

# %%
plt.figure(figsize=(12,7))
sns.barplot(x='loudness', y='track_name', data=top_5_loudest_tracks)
plt.title("Top Five Loudest Tracks")
plt.show()

# %% [markdown]
# Artist with most danceability song

# %%
top_5_artists_danceable_songs=df[['danceability', 'track_name', 'artists']].sort_values(by='danceability', ascending=False)[:5]
top_5_artists_danceable_songs
# Out:
#         danceability                                         track_name  \
# 111635         0.985                                           Sol Clap
# 66576          0.984                                      Medicaid Baby
# 24916          0.983                                        Inspiration
# 73374          0.982                                     Daily Routines
# 66793          0.981  Featuring Mixx Master Lee, Red Rum & J. Smoov ...
#
#                   artists
# 111635            Quantic
# 66576   That Girl Lay Lay
# 24916        Delano Smith
# 73374     Oliver Schories
# 66793     Mixx Master Lee

# %%
plt.figure(figsize=(12,7))
sns.barplot(x='danceability', y='artists', data=top_5_artists_danceable_songs)
plt.title("Top 5 Danceable Tracks")
plt.show()

# %% [markdown]
# Top 10 Instrumentalness tracks

# %%
top_10_instrumentalness_tracks=df[["instrumentalness", "track_name", "artists"]].sort_values(by="instrumentalness", ascending=False)[:10]
top_10_instrumentalness_tracks
# Out:
#         instrumentalness                    track_name  \
# 105149               1.0                       Shleepy
# 22922                1.0               The Truth Above
# 101771               1.0          Natural Ocean Sounds
# 101772               1.0  Soothing Thunderstorm Sounds
# 101774               1.0                Calming Hoover
# 101775               1.0             Chakra Meditation
# 101778               1.0                    Sova Musik
# 101781               1.0         Baby Sleep Pink Noise
# 101785               1.0                 Loopable Owls
# 101786               1.0             White Noise Waves
#
#                                                   artists
# 105149                                   Timothy Infinite
# 22922                                             Deicide
# 101771                             Sleep Recording Sounds
# 101772                                       Thunderstorm
# 101774                                     Silent Knights
# ...

# %%
plt.figure(figsize=(12,7))
plt.pie(x="instrumentalness", data=top_10_instrumentalness_tracks, autopct='%1.1f%%', labels=top_10_instrumentalness_tracks.track_name)
plt.show()
